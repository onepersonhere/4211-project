# %%
seed = 42
os.environ["PYTHONHASHSEED"]          = str(seed)
os.environ["TF_DETERMINISTIC_OPS"]    = "1"   # deterministic TF kernels
os.environ["OMP_NUM_THREADS"]         = "1"   # stop OpenMP racey reductions
os.environ["MKL_NUM_THREADS"]         = "1"
os.environ["TF_NUM_INTRAOP_THREADS"]  = "1"
os.environ["TF_NUM_INTEROP_THREADS"]  = "1"
# Uncomment next line if any teammate has an NVidia GPU
# os.environ["CUDA_VISIBLE_DEVICES"]  = "-1"
import numpy as np 
import random
random.seed(seed)
np.random.seed(seed)
import tensorflow as tf
tf.random.set_seed(seed)
tf.config.experimental.enable_op_determinism()

# %%
# Initial Setup & Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
import tensorflow as tf
from sklearn.preprocessing import RobustScaler 
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau 
from sklearn.model_selection import RandomizedSearchCV
from pandas.plotting import lag_plot
import matplotlib.ticker as mticker
import random
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the Dataset (Adjust file path if necessary)
df = pd.read_csv('./data_with_indicators/stock_prices_2minute_with_indicators.csv', parse_dates=['Datetime'])
df.set_index('Datetime', inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                        Open    High     Low   Close    Volume Ticker  \
# Datetime
# 2025-01-02 09:00:00  251.36  251.42  250.60  251.26    2009.0   AAPL
# 2025-01-02 09:00:00  190.00  190.36  189.86  190.36    3203.0  GOOGL
# 2025-01-02 09:00:00  220.44  221.41  220.25  220.89    2974.0   AMZN
# 2025-01-02 09:00:00  132.95  135.29  132.95  134.99  259293.0   NVDA
# 2025-01-02 09:00:00  408.00  412.42  408.00  412.14   83660.0   TSLA
#
#                           EMA12       EMA26       MACD    Signal  ...  \
# Datetime                                                          ...
# 2025-01-02 09:00:00  251.260000  251.260000   0.000000  0.000000  ...
# 2025-01-02 09:00:00  345.744958  360.581507 -14.836548 -3.121873  ...
# 2025-01-02 09:00:00  250.663851  253.578944  -2.915093 -0.675233  ...
# 2025-01-02 09:00:00  150.861465  152.431222  -1.569757 -0.370025  ...
# 2025-01-02 09:00:00  154.370969  130.138108  24.232862  4.792918  ...
#
#                      STOCHS_Sell        +DI        -DI        ADX  ADX_Buy  \
# Datetime
# 2025-01-02 09:00:00        False        NaN        NaN        NaN    False
# 2025-01-02 09:00:00        False   9.642143  -9.642143  17.652143    False
# 2025-01-02 09:00:00        False  30.460000 -30.460000  48.157449     True
# 2025-01-02 09:00:00        False  18.613571 -18.613571   6.268367    False
# 2025-01-02 09:00:00        False  36.540000 -36.540000  14.127653    False
#
#                      ADX_Sell  Aroon_Up  Aroon_Down  Aroon_Buy  Aroon_Sell
# Datetime
# 2025-01-02 09:00:00     False       NaN         NaN      False       False
# 2025-01-02 09:00:00      True       4.0        96.0      False        True
# 2025-01-02 09:00:00     False       8.0        96.0      False        True
# 2025-01-02 09:00:00      True       8.0        96.0      False        True
# 2025-01-02 09:00:00      True      96.0        88.0       True       False
#
# [5 rows x 47 columns]

# %%
# Add return target early for volatility plot
df['Return'] = df.groupby('Ticker')['Close'].pct_change().shift(-1)
df.dropna(subset=['Return'], inplace=True)

# Ensure Datetime is a column
df.reset_index(inplace=True) 

# Load both sentiment files
sent1 = pd.read_csv('../curr_news/aggregated_daily_sentiment.csv')
sent2 = pd.read_csv('../historic_news/aggregated_daily_sentiment.csv')

# Combine them in order: part 1 comes before part 2
sentiment = pd.concat([sent1, sent2], ignore_index=True)

# Rename and parse dates
sentiment.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
sentiment['Date'] = pd.to_datetime(sentiment['Date'])

# Reshape to long format: Date | Ticker | Sentiment
sentiment = sentiment.melt(id_vars='Date', var_name='Ticker', value_name='Sentiment')
sentiment['Date'] = sentiment['Date'].dt.normalize()
sentiment['Date'] = sentiment['Date'].dt.tz_localize(None)

# Prepare stock data date column
df['Date'] = df['Datetime'].dt.normalize()
df['Date'] = df['Date'].dt.tz_localize(None)

# Merge daily sentiment into intraday stock data
df = pd.merge(df, sentiment, how='left', on=['Date', 'Ticker'])
df.drop(columns='Date', inplace=True)

# Fill any missing sentiment values with neutral (0)
df['Sentiment'] = df['Sentiment'].fillna(0)

# %% [markdown]
# Model with News Sentiment

# %%
#Model with news sentiment
stocks = ["AAPL", "MSFT", "GOOGL", "NVDA", "TSLA", "AMZN", "META"] 
# Add return target for modeling and volatility plots
df['Return'] = df.groupby('Ticker')['Close'].pct_change().shift(-1)
df.dropna(subset=['Return'], inplace=True)

# Ensure correct datetime and indexing
df = df.sort_values(['Ticker', 'Datetime']).reset_index(drop=True)

# Prepare sequences for LSTM training
def prepare_sequences(df, feature_cols, sequence_length=20):
    feature_scaler = RobustScaler()
    return_scaler = RobustScaler()

    X_scaled = feature_scaler.fit_transform(df[feature_cols])
    y_scaled = return_scaler.fit_transform(df[['Return']])

    X_sequences, y_sequences, dates, close_prices = [], [], df['Datetime'].values[sequence_length:], df['Close'].values[sequence_length:]

    for i in range(len(X_scaled) - sequence_length):
        X_sequences.append(X_scaled[i:i+sequence_length])
        y_sequences.append(y_scaled[i+sequence_length])

    return np.array(X_sequences), np.array(y_sequences), dates, close_prices, return_scaler

# Improved LSTM model structure
def build_lstm_model(input_shape):
    model = Sequential([
        Bidirectional(LSTM(128, return_sequences=True), input_shape=input_shape),
        BatchNormalization(),
        Dropout(0.3, seed = seed),

        Bidirectional(LSTM(64, return_sequences=True)),
        BatchNormalization(),
        Dropout(0.3, seed = seed),

        LSTM(32, return_sequences=False),
        BatchNormalization(),
        Dropout(0.3, seed = seed),

        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(1, activation='tanh')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002), loss='mse', metrics=['mae'])
    return model

# Train and evaluate model
def train_and_evaluate(df, feature_cols, ticker):
    df_ticker = df[df['Ticker'] == ticker].copy()
    df_ticker = df_ticker.sort_values('Datetime').reset_index(drop=True)

    # Split by date
    train_data = df_ticker[df_ticker['Datetime'] < '2025-03-01']
    test_data = df_ticker[df_ticker['Datetime'] >= '2025-03-01']

    # Prepare sequences
    X_train, y_train, _, _, return_scaler = prepare_sequences(train_data, feature_cols)
    X_test, y_test, dates_test, close_prices_test, _ = prepare_sequences(test_data, feature_cols)

    model = build_lstm_model((X_train.shape[1], X_train.shape[2]))

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
    ]

    model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=callbacks
    )

    # Make predictions and inverse scale
    y_pred_scaled = model.predict(X_test)
    y_pred = return_scaler.inverse_transform(y_pred_scaled)
    y_test_actual = return_scaler.inverse_transform(y_test.reshape(-1, 1))

    # --- Apply trading strategy logic ---
    positions = np.where(y_pred.flatten() > 0, 'LONG', 'SHORT')
    strategy_returns = np.zeros_like(y_test_actual.flatten())

    for i in range(len(y_test_actual)):
        curr_position = positions[i]

        # Base return from position
        if curr_position == 'LONG':
            ret = y_test_actual[i]
        elif curr_position == 'SHORT':
            ret = -y_test_actual[i]
        else:
            ret = 0

        strategy_returns[i] = ret

    # Compute cumulative return
    cumulative_return = np.cumprod(1 + strategy_returns)

    # Compile into a DataFrame
    trades = pd.DataFrame({
        'Date': dates_test,
        'Close_Price': close_prices_test,
        'Actual_Return': y_test_actual.flatten(),
        'Predicted_Return': y_pred.flatten(),
        'Position': positions,
        'Strategy_Return': strategy_returns,
        'Cumulative_Return': cumulative_return,
        'Ticker': ticker
    })

    return trades


feature_cols = ['Close', 'MACD_Buy', 'MACD_Sell', 'RSI_Buy', 'RSI_Sell', 'STOCHS_Buy', 'STOCHS_Sell',
                'ADX_Buy', 'ADX_Sell', 'Aroon_Buy', 'Aroon_Sell', 'BOLL_Buy', 'BOLL_Sell', 'OSC_Buy', 'OSC_Sell', 'BIAS_Buy', 'BIAS_Sell',
                'Sentiment']

# Train models and compile trades
all_trades = []
for ticker in stocks:
    print(f"Training model for {ticker}...")
    trades = train_and_evaluate(df, feature_cols, ticker)
    all_trades.append(trades)

all_trades_df = pd.concat(all_trades, ignore_index=True)
# Out:
# Training model for AAPL...
# Epoch 1/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 26s 38ms/step - loss: 2.7752 - mae: 0.9926 - val_loss: 1.7187 - val_mae: 0.8405 - learning_rate: 2.0000e-04
# Epoch 2/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - loss: 2.5978 - mae: 0.9075 - val_loss: 1.6900 - val_mae: 0.8342 - learning_rate: 2.0000e-04
# Epoch 3/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - loss: 2.5728 - mae: 0.8967 - val_loss: 1.6815 - val_mae: 0.8262 - learning_rate: 2.0000e-04
# Epoch 4/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - loss: 2.5592 - mae: 0.8895 - val_loss: 1.6684 - val_mae: 0.8190 - learning_rate: 2.0000e-04
# Epoch 5/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 18s 35ms/step - loss: 2.5550 - mae: 0.8882 - val_loss: 1.6739 - val_mae: 0.8214 - learning_rate: 2.0000e-04
# Epoch 6/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - loss: 2.5483 - mae: 0.8877 - val_loss: 1.6671 - val_mae: 0.8184 - learning_rate: 2.0000e-04
# Epoch 7/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - loss: 2.5484 - mae: 0.8851 - val_loss: 1.6664 - val_mae: 0.8187 - learning_rate: 2.0000e-04
# Epoch 8/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 17s 32ms/step - loss: 2.5455 - mae: 0.8836 - val_loss: 1.6632 - val_mae: 0.8170 - learning_rate: 2.0000e-04
# Epoch 9/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 17s 32ms/step - loss: 2.5510 - mae: 0.8853 - val_loss: 1.6541 - val_mae: 0.8124 - learning_rate: 2.0000e-04
# Epoch 10/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 15s 29ms/step - loss: 2.5517 - mae: 0.8820 - val_loss: 1.6581 - val_mae: 0.8157 - learning_rate: 2.0000e-04
# Epoch 11/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 15s 29ms/step - loss: 2.5505 - mae: 0.8829 - val_loss: 1.6612 - val_mae: 0.8149 - learning_rate: 2.0000e-04
# Epoch 12/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.5411 - mae: 0.8816 - val_loss: 1.6570 - val_mae: 0.8145 - learning_rate: 2.0000e-04
# Epoch 13/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 18s 34ms/step - loss: 2.5518 - mae: 0.8823 - val_loss: 1.6572 - val_mae: 0.8134 - learning_rate: 2.0000e-04
# Epoch 14/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - loss: 2.5433 - mae: 0.8798 - val_loss: 1.6544 - val_mae: 0.8126 - learning_rate: 2.0000e-04
# Epoch 15/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - loss: 2.5479 - mae: 0.8806 - val_loss: 1.6549 - val_mae: 0.8128 - learning_rate: 4.0000e-05
# Epoch 16/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - loss: 2.5467 - mae: 0.8801 - val_loss: 1.6553 - val_mae: 0.8125 - learning_rate: 4.0000e-05
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step
# Training model for MSFT...
# Epoch 1/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - loss: 2.9835 - mae: 1.0838 - val_loss: 1.8123 - val_mae: 0.8706 - learning_rate: 2.0000e-04
# Epoch 2/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.6509 - mae: 0.9224 - val_loss: 1.7355 - val_mae: 0.8279 - learning_rate: 2.0000e-04
# Epoch 3/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 2.6395 - mae: 0.9120 - val_loss: 1.7142 - val_mae: 0.8208 - learning_rate: 2.0000e-04
# Epoch 4/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 2.6233 - mae: 0.9031 - val_loss: 1.7067 - val_mae: 0.8155 - learning_rate: 2.0000e-04
# Epoch 5/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 2.6228 - mae: 0.9017 - val_loss: 1.7039 - val_mae: 0.8130 - learning_rate: 2.0000e-04
# Epoch 6/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.6125 - mae: 0.8981 - val_loss: 1.7077 - val_mae: 0.8140 - learning_rate: 2.0000e-04
# Epoch 7/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.6086 - mae: 0.8936 - val_loss: 1.6932 - val_mae: 0.8073 - learning_rate: 2.0000e-04
# Epoch 8/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.5948 - mae: 0.8926 - val_loss: 1.6936 - val_mae: 0.8091 - learning_rate: 2.0000e-04
# Epoch 9/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.6076 - mae: 0.8914 - val_loss: 1.6904 - val_mae: 0.8090 - learning_rate: 2.0000e-04
# Epoch 10/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.5995 - mae: 0.8891 - val_loss: 1.6947 - val_mae: 0.8100 - learning_rate: 2.0000e-04
# Epoch 11/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.5959 - mae: 0.8891 - val_loss: 1.6862 - val_mae: 0.8057 - learning_rate: 2.0000e-04
# Epoch 12/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.5936 - mae: 0.8888 - val_loss: 1.6889 - val_mae: 0.8065 - learning_rate: 2.0000e-04
# Epoch 13/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.5965 - mae: 0.8894 - val_loss: 1.6880 - val_mae: 0.8061 - learning_rate: 2.0000e-04
# Epoch 14/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.5977 - mae: 0.8878 - val_loss: 1.7041 - val_mae: 0.8134 - learning_rate: 2.0000e-04
# Epoch 15/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 2.5923 - mae: 0.8886 - val_loss: 1.7069 - val_mae: 0.8155 - learning_rate: 2.0000e-04
# Epoch 16/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 2.5905 - mae: 0.8884 - val_loss: 1.6922 - val_mae: 0.8082 - learning_rate: 2.0000e-04
# Epoch 17/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 2.5931 - mae: 0.8873 - val_loss: 1.6903 - val_mae: 0.8072 - learning_rate: 4.0000e-05
# Epoch 18/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - loss: 2.5873 - mae: 0.8872 - val_loss: 1.6896 - val_mae: 0.8061 - learning_rate: 4.0000e-05
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Training model for GOOGL...
# Epoch 1/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - loss: 3.6084 - mae: 0.9707 - val_loss: 1.7871 - val_mae: 0.8415 - learning_rate: 2.0000e-04
# Epoch 2/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.5000 - mae: 0.9143 - val_loss: 1.7768 - val_mae: 0.8406 - learning_rate: 2.0000e-04
# Epoch 3/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4735 - mae: 0.9110 - val_loss: 1.7718 - val_mae: 0.8366 - learning_rate: 2.0000e-04
# Epoch 4/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4624 - mae: 0.8996 - val_loss: 1.7686 - val_mae: 0.8347 - learning_rate: 2.0000e-04
# Epoch 5/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.4535 - mae: 0.8945 - val_loss: 1.7651 - val_mae: 0.8322 - learning_rate: 2.0000e-04
# Epoch 6/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4596 - mae: 0.8949 - val_loss: 1.7662 - val_mae: 0.8326 - learning_rate: 2.0000e-04
# Epoch 7/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4429 - mae: 0.8943 - val_loss: 1.7599 - val_mae: 0.8289 - learning_rate: 2.0000e-04
# Epoch 8/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4518 - mae: 0.8925 - val_loss: 1.7644 - val_mae: 0.8313 - learning_rate: 2.0000e-04
# Epoch 9/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - loss: 3.4326 - mae: 0.8896 - val_loss: 1.7626 - val_mae: 0.8313 - learning_rate: 2.0000e-04
# Epoch 10/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.4505 - mae: 0.8916 - val_loss: 1.7611 - val_mae: 0.8292 - learning_rate: 2.0000e-04
# Epoch 11/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4460 - mae: 0.8907 - val_loss: 1.7594 - val_mae: 0.8311 - learning_rate: 2.0000e-04
# Epoch 12/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4403 - mae: 0.8895 - val_loss: 1.7666 - val_mae: 0.8327 - learning_rate: 2.0000e-04
# Epoch 13/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4447 - mae: 0.8910 - val_loss: 1.7653 - val_mae: 0.8303 - learning_rate: 2.0000e-04
# Epoch 14/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.4390 - mae: 0.8885 - val_loss: 1.7615 - val_mae: 0.8299 - learning_rate: 2.0000e-04
# Epoch 15/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4423 - mae: 0.8890 - val_loss: 1.7601 - val_mae: 0.8296 - learning_rate: 2.0000e-04
# Epoch 16/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4416 - mae: 0.8887 - val_loss: 1.7582 - val_mae: 0.8285 - learning_rate: 2.0000e-04
# Epoch 17/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4376 - mae: 0.8867 - val_loss: 1.7618 - val_mae: 0.8295 - learning_rate: 2.0000e-04
# Epoch 18/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4392 - mae: 0.8865 - val_loss: 1.7642 - val_mae: 0.8297 - learning_rate: 2.0000e-04
# Epoch 19/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4384 - mae: 0.8868 - val_loss: 1.7670 - val_mae: 0.8307 - learning_rate: 2.0000e-04
# Epoch 20/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.4356 - mae: 0.8879 - val_loss: 1.7651 - val_mae: 0.8302 - learning_rate: 2.0000e-04
# Epoch 21/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 3.4376 - mae: 0.8873 - val_loss: 1.7670 - val_mae: 0.8312 - learning_rate: 2.0000e-04
# Epoch 22/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 3.4389 - mae: 0.8889 - val_loss: 1.7660 - val_mae: 0.8315 - learning_rate: 4.0000e-05
# Epoch 23/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 15s 30ms/step - loss: 3.4300 - mae: 0.8849 - val_loss: 1.7674 - val_mae: 0.8321 - learning_rate: 4.0000e-05
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Training model for NVDA...
# Epoch 1/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - loss: 3.2433 - mae: 0.9366 - val_loss: 1.6786 - val_mae: 0.8302 - learning_rate: 2.0000e-04
# Epoch 2/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 3.1839 - mae: 0.8963 - val_loss: 1.6721 - val_mae: 0.8316 - learning_rate: 2.0000e-04
# Epoch 3/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 3.1594 - mae: 0.8841 - val_loss: 1.6562 - val_mae: 0.8215 - learning_rate: 2.0000e-04
# Epoch 4/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 3.1422 - mae: 0.8793 - val_loss: 1.6531 - val_mae: 0.8170 - learning_rate: 2.0000e-04
# Epoch 5/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 3.1471 - mae: 0.8771 - val_loss: 1.6496 - val_mae: 0.8150 - learning_rate: 2.0000e-04
# Epoch 6/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 3.1339 - mae: 0.8728 - val_loss: 1.6387 - val_mae: 0.8095 - learning_rate: 2.0000e-04
# Epoch 7/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 3.1359 - mae: 0.8725 - val_loss: 1.6407 - val_mae: 0.8114 - learning_rate: 2.0000e-04
# Epoch 8/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 3.1332 - mae: 0.8729 - val_loss: 1.6381 - val_mae: 0.8100 - learning_rate: 2.0000e-04
# Epoch 9/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 3.1393 - mae: 0.8702 - val_loss: 1.6362 - val_mae: 0.8081 - learning_rate: 2.0000e-04
# Epoch 10/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 3.1335 - mae: 0.8697 - val_loss: 1.6362 - val_mae: 0.8071 - learning_rate: 2.0000e-04
# Epoch 11/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - loss: 3.1337 - mae: 0.8694 - val_loss: 1.6344 - val_mae: 0.8069 - learning_rate: 2.0000e-04
# Epoch 12/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 3.1362 - mae: 0.8716 - val_loss: 1.6347 - val_mae: 0.8062 - learning_rate: 2.0000e-04
# Epoch 13/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 3.1394 - mae: 0.8702 - val_loss: 1.6348 - val_mae: 0.8062 - learning_rate: 2.0000e-04
# Epoch 14/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 3.1358 - mae: 0.8695 - val_loss: 1.6345 - val_mae: 0.8061 - learning_rate: 2.0000e-04
# Epoch 15/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 3.1335 - mae: 0.8690 - val_loss: 1.6336 - val_mae: 0.8059 - learning_rate: 2.0000e-04
# Epoch 16/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 3.1316 - mae: 0.8690 - val_loss: 1.6337 - val_mae: 0.8060 - learning_rate: 2.0000e-04
# Epoch 17/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 3.1326 - mae: 0.8692 - val_loss: 1.6356 - val_mae: 0.8064 - learning_rate: 2.0000e-04
# Epoch 18/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 3.1313 - mae: 0.8680 - val_loss: 1.6366 - val_mae: 0.8070 - learning_rate: 2.0000e-04
# Epoch 19/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 3.1320 - mae: 0.8687 - val_loss: 1.6352 - val_mae: 0.8063 - learning_rate: 2.0000e-04
# Epoch 20/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 3.1331 - mae: 0.8690 - val_loss: 1.6346 - val_mae: 0.8060 - learning_rate: 2.0000e-04
# Epoch 21/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 3.1324 - mae: 0.8687 - val_loss: 1.6348 - val_mae: 0.8060 - learning_rate: 4.0000e-05
# Epoch 22/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - loss: 3.1304 - mae: 0.8692 - val_loss: 1.6348 - val_mae: 0.8062 - learning_rate: 4.0000e-05
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step
# Training model for TSLA...
# Epoch 1/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - loss: 2.6737 - mae: 1.0049 - val_loss: 1.7335 - val_mae: 0.8423 - learning_rate: 2.0000e-04
# Epoch 2/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - loss: 2.4892 - mae: 0.9100 - val_loss: 1.6976 - val_mae: 0.8231 - learning_rate: 2.0000e-04
# Epoch 3/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - loss: 2.4354 - mae: 0.8849 - val_loss: 1.6947 - val_mae: 0.8200 - learning_rate: 2.0000e-04
# Epoch 4/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - loss: 2.4315 - mae: 0.8836 - val_loss: 1.6834 - val_mae: 0.8137 - learning_rate: 2.0000e-04
# Epoch 5/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - loss: 2.4175 - mae: 0.8772 - val_loss: 1.6781 - val_mae: 0.8102 - learning_rate: 2.0000e-04
# Epoch 6/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.4185 - mae: 0.8793 - val_loss: 1.6882 - val_mae: 0.8155 - learning_rate: 2.0000e-04
# Epoch 7/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4118 - mae: 0.8747 - val_loss: 1.6818 - val_mae: 0.8123 - learning_rate: 2.0000e-04
# Epoch 8/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4082 - mae: 0.8710 - val_loss: 1.6773 - val_mae: 0.8088 - learning_rate: 2.0000e-04
# Epoch 9/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4106 - mae: 0.8736 - val_loss: 1.6827 - val_mae: 0.8117 - learning_rate: 2.0000e-04
# Epoch 10/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4088 - mae: 0.8702 - val_loss: 1.6807 - val_mae: 0.8108 - learning_rate: 2.0000e-04
# Epoch 11/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4000 - mae: 0.8672 - val_loss: 1.6777 - val_mae: 0.8092 - learning_rate: 2.0000e-04
# Epoch 12/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4026 - mae: 0.8687 - val_loss: 1.6769 - val_mae: 0.8082 - learning_rate: 2.0000e-04
# Epoch 13/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4028 - mae: 0.8680 - val_loss: 1.6814 - val_mae: 0.8095 - learning_rate: 2.0000e-04
# Epoch 14/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - loss: 2.3997 - mae: 0.8687 - val_loss: 1.6805 - val_mae: 0.8091 - learning_rate: 2.0000e-04
# Epoch 15/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.3981 - mae: 0.8679 - val_loss: 1.6762 - val_mae: 0.8091 - learning_rate: 2.0000e-04
# Epoch 16/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.3968 - mae: 0.8661 - val_loss: 1.6797 - val_mae: 0.8088 - learning_rate: 2.0000e-04
# Epoch 17/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4008 - mae: 0.8676 - val_loss: 1.6794 - val_mae: 0.8082 - learning_rate: 2.0000e-04
# Epoch 18/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.3962 - mae: 0.8671 - val_loss: 1.6842 - val_mae: 0.8109 - learning_rate: 2.0000e-04
# Epoch 19/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.4023 - mae: 0.8673 - val_loss: 1.6816 - val_mae: 0.8105 - learning_rate: 2.0000e-04
# Epoch 20/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - loss: 2.3980 - mae: 0.8658 - val_loss: 1.6819 - val_mae: 0.8106 - learning_rate: 2.0000e-04
# Epoch 21/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - loss: 2.3906 - mae: 0.8645 - val_loss: 1.6801 - val_mae: 0.8096 - learning_rate: 4.0000e-05
# Epoch 22/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.3954 - mae: 0.8651

# %%
def run_sensitivity_analysis(df):
    """
    Perform sensitivity analysis by adjusting the predicted returns and evaluating final cumulative return.
    """
      # Define the adjustment factors internally
    factors = [0.5, 0.8, 0.9, 1.0, 1.1, 1.2, 1.5]
    
    results = []
    for factor in factors:
        # Adjust the predicted returns using the factor
        adjusted_predicted = df['Predicted_Return'] * factor
        
        # Determine the trading position: long (1) if adjusted predicted >= 0, otherwise short (-1)
        positions = np.where(adjusted_predicted >= 0, 1, -1)
        
        # Compute the strategy returns using the actual return (which remains unchanged)
        strategy_returns = positions * df['Actual_Return']
        
        # Compute cumulative returns for the strategy
        cumulative_returns = (1 + strategy_returns).cumprod()
        
        # Final cumulative return is the last value in the cumulative return series
        final_cum_return = cumulative_returns.iloc[-1]
        
        results.append({
            'Adjustment_Factor': factor,
            'Final_Cumulative_Return': final_cum_return
        })
    
    # Convert the results list to a DataFrame and return it
    results_df = pd.DataFrame(results)
    return results_df



# Stress testing function
def run_stress_testing(df):
    """
    Perform stress tests by simulating various market shock scenarios.
    """
    scenarios = {
        'Crash': df['Actual_Return'] - 0.00005,  
        'Volatility_Spike': df['Actual_Return'] + np.random.normal(0, 0.00002, size=len(df)),
        'Prediction_Inverted': -df['Predicted_Return'],
        'Zero_Prediction': np.zeros_like(df['Predicted_Return']), 
        'Normal': df['Actual_Return']
    }

    results = []
    for scenario_name, shock in scenarios.items():
        df_temp = df.copy()

        if 'Prediction' in scenario_name:
            df_temp['Adj_Predicted_Return'] = shock
        else:
            df_temp['Adj_Predicted_Return'] = df_temp['Predicted_Return']
            df_temp['Actual_Return'] = shock

        positions = np.where(df_temp['Adj_Predicted_Return'] > 0, 'LONG', 'SHORT')
        strategy_returns = np.zeros_like(df_temp['Actual_Return'])

        for i in range(len(df_temp)):
            curr_position = positions[i]
            actual_ret = df_temp.loc[i, 'Actual_Return']

            if curr_position == 'LONG':
                ret = actual_ret
            elif curr_position == 'SHORT':
                ret = -actual_ret
            else:
                ret = 0

            strategy_returns[i] = ret

        cumulative_return = np.cumprod(1 + strategy_returns)[-1]
        results.append((scenario_name, cumulative_return))

    df_stress = pd.DataFrame(results, columns=["Scenario", "Final_Cumulative_Return"])
    return df_stress


def calculate_trade_metrics(df):
    """
    Calculate trade statistics from a DataFrame containing trading data.

    Parameters:
        df (pandas.DataFrame): The DataFrame containing the trading data. It must include 
                               the columns 'Date', 'Actual_Return', and 'Position'.

    Returns:
        dict: A dictionary containing the number of trades, average holding period (in minutes),
              and average profit per trade.
    """
    # Ensure 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Identify trades by detecting changes in 'Position'
    df['Trade_ID'] = (df['Position'] != df['Position'].shift(1)).cumsum()
    
    # Function to compute the trade return based on the trade's position.
    def calc_trade_return(group):
        pos = group['Position'].iloc[0].upper()
        if pos == "LONG":
            return np.prod(1 + group['Actual_Return']) - 1
        elif pos == "SHORT":
            return np.prod(1 - group['Actual_Return']) - 1
        else:
            return np.nan

    # Compute trade-level metrics: start and end times, and the trade's return.
    trade_metrics = df.groupby('Trade_ID').agg(
        start_date=('Date', 'first'),
        end_date=('Date', 'last'),
        position=('Position', 'first')
    ).reset_index()

    trade_metrics['trade_return'] = df.groupby('Trade_ID').apply(calc_trade_return).values
    trade_metrics['holding_period_minutes'] = (
        (trade_metrics['end_date'] - trade_metrics['start_date']).dt.total_seconds() / 60
    )
    
    # Calculate overall metrics
    num_trades = trade_metrics.shape[0]
    avg_holding_period = trade_metrics['holding_period_minutes'].mean()
    avg_profit_per_trade = trade_metrics['trade_return'].mean()

    return {
        'num_trades': num_trades,
        'avg_holding_period_minutes': avg_holding_period,
        'avg_profit_per_trade': avg_profit_per_trade
    }

# %%
# Create a dictionary of DataFrames, one for each ticker
ticker_dfs = {ticker: group.copy() for ticker, group in all_trades_df.groupby("Ticker")}

aapl_trades = ticker_dfs.get('AAPL') 
nvda_trades = ticker_dfs.get('NVDA')  
amzn_trades = ticker_dfs.get('AMZN')  
tsla_trades = ticker_dfs.get('TSLA')  
googl_trades = ticker_dfs.get('GOOGL') 
msft_trades = ticker_dfs.get('MSFT') 
meta_trades = ticker_dfs.get('META')

# %%
run_sensitivity_analysis(aapl_trades)
# Out:
#    Adjustment_Factor  Final_Cumulative_Return
# 0                0.5                 1.144384
# 1                0.8                 1.144384
# 2                0.9                 1.144384
# 3                1.0                 1.144384
# 4                1.1                 1.144384
# 5                1.2                 1.144384
# 6                1.5                 1.144384

# %%
run_sensitivity_analysis(nvda_trades)
# Out:
#    Adjustment_Factor  Final_Cumulative_Return
# 0                0.5                 0.943386
# 1                0.8                 0.943386
# 2                0.9                 0.943386
# 3                1.0                 0.943386
# 4                1.1                 0.943386
# 5                1.2                 0.943386
# 6                1.5                 0.943386

# %%
run_sensitivity_analysis(amzn_trades)
# Out:
#    Adjustment_Factor  Final_Cumulative_Return
# 0                0.5                 1.096944
# 1                0.8                 1.096944
# 2                0.9                 1.096944
# 3                1.0                 1.096944
# 4                1.1                 1.096944
# 5                1.2                 1.096944
# 6                1.5                 1.096944

# %%
run_sensitivity_analysis(tsla_trades)
# Out:
#    Adjustment_Factor  Final_Cumulative_Return
# 0                0.5                 1.189741
# 1                0.8                 1.189741
# 2                0.9                 1.189741
# 3                1.0                 1.189741
# 4                1.1                 1.189741
# 5                1.2                 1.189741
# 6                1.5                 1.189741

# %%
run_sensitivity_analysis(googl_trades)
# Out:
#    Adjustment_Factor  Final_Cumulative_Return
# 0                0.5                 1.067617
# 1                0.8                 1.067617
# 2                0.9                 1.067617
# 3                1.0                 1.067617
# 4                1.1                 1.067617
# 5                1.2                 1.067617
# 6                1.5                 1.067617

# %%
run_sensitivity_analysis(msft_trades)
# Out:
#    Adjustment_Factor  Final_Cumulative_Return
# 0                0.5                 0.889788
# 1                0.8                 0.889788
# 2                0.9                 0.889788
# 3                1.0                 0.889788
# 4                1.1                 0.889788
# 5                1.2                 0.889788
# 6                1.5                 0.889788

# %%
run_sensitivity_analysis(meta_trades)
# Out:
#    Adjustment_Factor  Final_Cumulative_Return
# 0                0.5                 1.295315
# 1                0.8                 1.295315
# 2                0.9                 1.295315
# 3                1.0                 1.295315
# 4                1.1                 1.295315
# 5                1.2                 1.295315
# 6                1.5                 1.295315

# %%
run_stress_testing(aapl_trades)
# Out:
#               Scenario  Final_Cumulative_Return
# 0                Crash                 1.335154
# 1     Volatility_Spike                 1.144085
# 2  Prediction_Inverted                 0.863815
# 3      Zero_Prediction                 1.194013
# 4               Normal                 1.144384

# %%
nvda_trades.reset_index(drop=True, inplace=True)
run_stress_testing(nvda_trades)
# Out:
#               Scenario  Final_Cumulative_Return
# 0                Crash                 0.878975
# 1     Volatility_Spike                 0.945359
# 2  Prediction_Inverted                 1.049793
# 3      Zero_Prediction                 1.127236
# 4               Normal                 0.943386

# %%
tsla_trades.reset_index(drop=True, inplace=True)
run_stress_testing(tsla_trades)
# Out:
#               Scenario  Final_Cumulative_Return
# 0                Crash                 1.216979
# 1     Volatility_Spike                 1.190840
# 2  Prediction_Inverted                 0.832551
# 3      Zero_Prediction                 1.026620
# 4               Normal                 1.189741

# %%
amzn_trades.reset_index(drop=True, inplace=True)
run_stress_testing(amzn_trades)
# Out:
#               Scenario  Final_Cumulative_Return
# 0                Crash                 1.337453
# 1     Volatility_Spike                 1.100223
# 2  Prediction_Inverted                 0.901586
# 3      Zero_Prediction                 1.000364
# 4               Normal                 1.096944

# %%
msft_trades.reset_index(drop=True, inplace=True)
run_stress_testing(msft_trades)
# Out:
#               Scenario  Final_Cumulative_Return
# 0                Crash                 0.705085
# 1     Volatility_Spike                 0.891831
# 2  Prediction_Inverted                 1.111328
# 3      Zero_Prediction                 1.080392
# 4               Normal                 0.889788

# %%
meta_trades.reset_index(drop=True, inplace=True)
run_stress_testing(meta_trades)
# Out:
#               Scenario  Final_Cumulative_Return
# 0                Crash                 1.301530
# 1     Volatility_Spike                 1.294490
# 2  Prediction_Inverted                 0.762979
# 3      Zero_Prediction                 1.063171
# 4               Normal                 1.295315

# %%
googl_trades.reset_index(drop=True, inplace=True)
run_stress_testing(googl_trades)
# Out:
#               Scenario  Final_Cumulative_Return
# 0                Crash                 1.284174
# 1     Volatility_Spike                 1.069270
# 2  Prediction_Inverted                 0.924840
# 3      Zero_Prediction                 1.055808
# 4               Normal                 1.067617

# %%
calculate_trade_metrics(nvda_trades)
# Out:
# {'num_trades': 1189,
#  'avg_holding_period_minutes': 31.069806560134566,
#  'avg_profit_per_trade': -4.4939129240626737e-05}

# %%
calculate_trade_metrics(aapl_trades)
# Out:
# {'num_trades': 781,
#  'avg_holding_period_minutes': 45.53137003841229,
#  'avg_profit_per_trade': 0.00017972702179927934}

# %%
calculate_trade_metrics(googl_trades)
# Out:
# {'num_trades': 1022,
#  'avg_holding_period_minutes': 34.32681017612524,
#  'avg_profit_per_trade': 7.042586914690978e-05}

# %%
calculate_trade_metrics(msft_trades)
# Out:
# {'num_trades': 461,
#  'avg_holding_period_minutes': 78.61605206073753,
#  'avg_profit_per_trade': -0.00023845796294881655}

# %%
calculate_trade_metrics(meta_trades)
# Out:
# {'num_trades': 954,
#  'avg_holding_period_minutes': 40.0482180293501,
#  'avg_profit_per_trade': 0.00027826479603170715}

# %%
calculate_trade_metrics(tsla_trades)
# Out:
# {'num_trades': 1407,
#  'avg_holding_period_minutes': 26.287135749822315,
#  'avg_profit_per_trade': 0.00012750538856760253}

# %%
calculate_trade_metrics(amzn_trades)
# Out:
# {'num_trades': 1063,
#  'avg_holding_period_minutes': 35.25682031984948,
#  'avg_profit_per_trade': 9.295368718242024e-05}

# %% [markdown]
# Model without News Sentiment

# %%
#Model without news sentiment
stocks = ["AAPL", "MSFT", "GOOGL", "NVDA", "TSLA", "AMZN", "META"] 
# Add return target for modeling and volatility plots
df['Return'] = df.groupby('Ticker')['Close'].pct_change().shift(-1)
df.dropna(subset=['Return'], inplace=True)

# Ensure correct datetime and indexing
df = df.sort_values(['Ticker', 'Datetime']).reset_index(drop=True)

# Prepare sequences for LSTM training
def prepare_sequences(df, feature_cols, sequence_length=20):
    feature_scaler = RobustScaler()
    return_scaler = RobustScaler()

    X_scaled = feature_scaler.fit_transform(df[feature_cols])
    y_scaled = return_scaler.fit_transform(df[['Return']])

    X_sequences, y_sequences, dates, close_prices = [], [], df['Datetime'].values[sequence_length:], df['Close'].values[sequence_length:]

    for i in range(len(X_scaled) - sequence_length):
        X_sequences.append(X_scaled[i:i+sequence_length])
        y_sequences.append(y_scaled[i+sequence_length])

    return np.array(X_sequences), np.array(y_sequences), dates, close_prices, return_scaler

# Improved LSTM model structure
def build_lstm_model(input_shape):
    model = Sequential([
        Bidirectional(LSTM(128, return_sequences=True), input_shape=input_shape),
        BatchNormalization(),
        Dropout(0.3),

        Bidirectional(LSTM(64, return_sequences=True)),
        BatchNormalization(),
        Dropout(0.3),

        LSTM(32, return_sequences=False),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(1, activation='tanh')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002), loss='mse', metrics=['mae'])
    return model

# Train and evaluate model
def train_and_evaluate(df, feature_cols, ticker):
    df_ticker = df[df['Ticker'] == ticker].copy()
    df_ticker = df_ticker.sort_values('Datetime').reset_index(drop=True)

    # Split by date
    train_data = df_ticker[df_ticker['Datetime'] < '2025-03-01']
    test_data = df_ticker[df_ticker['Datetime'] >= '2025-03-01']

    # Prepare sequences
    X_train, y_train, _, _, return_scaler = prepare_sequences(train_data, feature_cols)
    X_test, y_test, dates_test, close_prices_test, _ = prepare_sequences(test_data, feature_cols)

    model = build_lstm_model((X_train.shape[1], X_train.shape[2]))

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
    ]

    model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=callbacks
    )

    # Make predictions and inverse scale
    y_pred_scaled = model.predict(X_test)
    y_pred = return_scaler.inverse_transform(y_pred_scaled)
    y_test_actual = return_scaler.inverse_transform(y_test.reshape(-1, 1))

    # --- Apply trading strategy logic ---
    positions = np.where(y_pred.flatten() > 0, 'LONG', 'SHORT')
    strategy_returns = np.zeros_like(y_test_actual.flatten())

    for i in range(len(y_test_actual)):
        curr_position = positions[i]

        # Base return from position
        if curr_position == 'LONG':
            ret = y_test_actual[i]
        elif curr_position == 'SHORT':
            ret = -y_test_actual[i]
        else:
            ret = 0

        strategy_returns[i] = ret

    # Compute cumulative return
    cumulative_return = np.cumprod(1 + strategy_returns)

    # Compile into a DataFrame
    trades = pd.DataFrame({
        'Date': dates_test,
        'Close_Price': close_prices_test,
        'Actual_Return': y_test_actual.flatten(),
        'Predicted_Return': y_pred.flatten(),
        'Position': positions,
        'Strategy_Return': strategy_returns,
        'Cumulative_Return': cumulative_return,
        'Ticker': ticker
    })

    return trades


feature_cols = ['Close', 'MACD_Buy', 'MACD_Sell', 'RSI_Buy', 'RSI_Sell', 'STOCHS_Buy', 'STOCHS_Sell',
                'ADX_Buy', 'ADX_Sell', 'Aroon_Buy', 'Aroon_Sell', 'BOLL_Buy', 'BOLL_Sell', 'OSC_Buy', 'OSC_Sell', 'BIAS_Buy', 'BIAS_Sell',
                ]

# Train models and compile trades
all_trades = []
for ticker in stocks:
    print(f"Training model for {ticker}...")
    trades = train_and_evaluate(df, feature_cols, ticker)
    all_trades.append(trades)

all_trades_df_no_news = pd.concat(all_trades, ignore_index=True)
# Out:
# Training model for AAPL...
# Epoch 1/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 2.0838 - mae: 0.8651 - val_loss: 1.4321 - val_mae: 0.7993 - learning_rate: 2.0000e-04
# Epoch 2/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.0225 - mae: 0.8285 - val_loss: 1.4236 - val_mae: 0.7911 - learning_rate: 2.0000e-04
# Epoch 3/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 27ms/step - loss: 1.9942 - mae: 0.8193 - val_loss: 1.4101 - val_mae: 0.7841 - learning_rate: 2.0000e-04
# Epoch 4/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 27ms/step - loss: 1.9999 - mae: 0.8180 - val_loss: 1.4020 - val_mae: 0.7789 - learning_rate: 2.0000e-04
# Epoch 5/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 27ms/step - loss: 1.9837 - mae: 0.8116 - val_loss: 1.4022 - val_mae: 0.7803 - learning_rate: 2.0000e-04
# Epoch 6/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 1.9818 - mae: 0.8104 - val_loss: 1.4065 - val_mae: 0.7806 - learning_rate: 2.0000e-04
# Epoch 7/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 27ms/step - loss: 1.9786 - mae: 0.8125 - val_loss: 1.4025 - val_mae: 0.7791 - learning_rate: 2.0000e-04
# Epoch 8/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 1.9774 - mae: 0.8095 - val_loss: 1.4039 - val_mae: 0.7798 - learning_rate: 2.0000e-04
# Epoch 9/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 1.9812 - mae: 0.8086 - val_loss: 1.4064 - val_mae: 0.7792 - learning_rate: 2.0000e-04
# Epoch 10/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 1.9773 - mae: 0.8063 - val_loss: 1.4109 - val_mae: 0.7823 - learning_rate: 4.0000e-05
# Epoch 11/50
# 522/522 ━━━━━━━━━━━━━━━━━━━━ 14s 27ms/step - loss: 1.9720 - mae: 0.8046 - val_loss: 1.4097 - val_mae: 0.7816 - learning_rate: 4.0000e-05
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Training model for MSFT...
# Epoch 1/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 18s 27ms/step - loss: 2.0097 - mae: 0.8910 - val_loss: 1.3152 - val_mae: 0.7759 - learning_rate: 2.0000e-04
# Epoch 2/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8694 - mae: 0.8304 - val_loss: 1.2720 - val_mae: 0.7584 - learning_rate: 2.0000e-04
# Epoch 3/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8543 - mae: 0.8151 - val_loss: 1.2779 - val_mae: 0.7566 - learning_rate: 2.0000e-04
# Epoch 4/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8374 - mae: 0.8069 - val_loss: 1.2780 - val_mae: 0.7530 - learning_rate: 2.0000e-04
# Epoch 5/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - loss: 1.8139 - mae: 0.8013 - val_loss: 1.2616 - val_mae: 0.7491 - learning_rate: 2.0000e-04
# Epoch 6/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8265 - mae: 0.8011 - val_loss: 1.2560 - val_mae: 0.7459 - learning_rate: 2.0000e-04
# Epoch 7/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8199 - mae: 0.7976 - val_loss: 1.2558 - val_mae: 0.7421 - learning_rate: 2.0000e-04
# Epoch 8/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8268 - mae: 0.7979 - val_loss: 1.2578 - val_mae: 0.7428 - learning_rate: 2.0000e-04
# Epoch 9/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8196 - mae: 0.7974 - val_loss: 1.2604 - val_mae: 0.7451 - learning_rate: 2.0000e-04
# Epoch 10/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8198 - mae: 0.7964 - val_loss: 1.2624 - val_mae: 0.7447 - learning_rate: 2.0000e-04
# Epoch 11/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8122 - mae: 0.7945 - val_loss: 1.2579 - val_mae: 0.7428 - learning_rate: 2.0000e-04
# Epoch 12/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8156 - mae: 0.7956 - val_loss: 1.2508 - val_mae: 0.7384 - learning_rate: 2.0000e-04
# Epoch 13/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8201 - mae: 0.7950 - val_loss: 1.2509 - val_mae: 0.7399 - learning_rate: 2.0000e-04
# Epoch 14/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8149 - mae: 0.7948 - val_loss: 1.2492 - val_mae: 0.7391 - learning_rate: 2.0000e-04
# Epoch 15/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8096 - mae: 0.7924 - val_loss: 1.2486 - val_mae: 0.7390 - learning_rate: 2.0000e-04
# Epoch 16/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8134 - mae: 0.7935 - val_loss: 1.2510 - val_mae: 0.7400 - learning_rate: 2.0000e-04
# Epoch 17/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8155 - mae: 0.7944 - val_loss: 1.2457 - val_mae: 0.7363 - learning_rate: 2.0000e-04
# Epoch 18/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8094 - mae: 0.7923 - val_loss: 1.2461 - val_mae: 0.7376 - learning_rate: 2.0000e-04
# Epoch 19/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8142 - mae: 0.7927 - val_loss: 1.2453 - val_mae: 0.7366 - learning_rate: 2.0000e-04
# Epoch 20/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8107 - mae: 0.7937 - val_loss: 1.2422 - val_mae: 0.7344 - learning_rate: 2.0000e-04
# Epoch 21/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8130 - mae: 0.7931 - val_loss: 1.2428 - val_mae: 0.7348 - learning_rate: 2.0000e-04
# Epoch 22/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - loss: 1.8106 - mae: 0.7922 - val_loss: 1.2421 - val_mae: 0.7351 - learning_rate: 2.0000e-04
# Epoch 23/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8137 - mae: 0.7920 - val_loss: 1.2435 - val_mae: 0.7355 - learning_rate: 2.0000e-04
# Epoch 24/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8067 - mae: 0.7917 - val_loss: 1.2438 - val_mae: 0.7353 - learning_rate: 2.0000e-04
# Epoch 25/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 1.8054 - mae: 0.7902 - val_loss: 1.2427 - val_mae: 0.7356 - learning_rate: 2.0000e-04
# Epoch 26/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - loss: 1.8050 - mae: 0.7897 - val_loss: 1.2427 - val_mae: 0.7357 - learning_rate: 2.0000e-04
# Epoch 27/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - loss: 1.8089 - mae: 0.7889 - val_loss: 1.2434 - val_mae: 0.7359 - learning_rate: 2.0000e-04
# Epoch 28/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - loss: 1.8017 - mae: 0.7884 - val_loss: 1.2438 - val_mae: 0.7362 - learning_rate: 4.0000e-05
# Epoch 29/50
# 459/459 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - loss: 1.7984 - mae: 0.7884 - val_loss: 1.2432 - val_mae: 0.7358 - learning_rate: 4.0000e-05
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Training model for GOOGL...
# Epoch 1/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 4.4124 - mae: 0.9224 - val_loss: 1.1565 - val_mae: 0.7437 - learning_rate: 2.0000e-04
# Epoch 2/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2782 - mae: 0.8605 - val_loss: 1.1516 - val_mae: 0.7385 - learning_rate: 2.0000e-04
# Epoch 3/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2738 - mae: 0.8503 - val_loss: 1.1349 - val_mae: 0.7313 - learning_rate: 2.0000e-04
# Epoch 4/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2428 - mae: 0.8424 - val_loss: 1.1369 - val_mae: 0.7311 - learning_rate: 2.0000e-04
# Epoch 5/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2447 - mae: 0.8401 - val_loss: 1.1301 - val_mae: 0.7249 - learning_rate: 2.0000e-04
# Epoch 6/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2440 - mae: 0.8342 - val_loss: 1.1318 - val_mae: 0.7266 - learning_rate: 2.0000e-04
# Epoch 7/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2336 - mae: 0.8350 - val_loss: 1.1346 - val_mae: 0.7266 - learning_rate: 2.0000e-04
# Epoch 8/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2323 - mae: 0.8317 - val_loss: 1.1317 - val_mae: 0.7255 - learning_rate: 2.0000e-04
# Epoch 9/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2361 - mae: 0.8323 - val_loss: 1.1304 - val_mae: 0.7245 - learning_rate: 2.0000e-04
# Epoch 10/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2466 - mae: 0.8311 - val_loss: 1.1267 - val_mae: 0.7235 - learning_rate: 2.0000e-04
# Epoch 11/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2234 - mae: 0.8293 - val_loss: 1.1245 - val_mae: 0.7221 - learning_rate: 2.0000e-04
# Epoch 12/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2138 - mae: 0.8280 - val_loss: 1.1266 - val_mae: 0.7239 - learning_rate: 2.0000e-04
# Epoch 13/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2120 - mae: 0.8276 - val_loss: 1.1215 - val_mae: 0.7202 - learning_rate: 2.0000e-04
# Epoch 14/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - loss: 4.2129 - mae: 0.8268 - val_loss: 1.1251 - val_mae: 0.7241 - learning_rate: 2.0000e-04
# Epoch 15/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2197 - mae: 0.8289 - val_loss: 1.1225 - val_mae: 0.7208 - learning_rate: 2.0000e-04
# Epoch 16/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2206 - mae: 0.8273 - val_loss: 1.1222 - val_mae: 0.7212 - learning_rate: 2.0000e-04
# Epoch 17/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2268 - mae: 0.8242 - val_loss: 1.1208 - val_mae: 0.7198 - learning_rate: 2.0000e-04
# Epoch 18/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2104 - mae: 0.8238 - val_loss: 1.1236 - val_mae: 0.7214 - learning_rate: 2.0000e-04
# Epoch 19/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2202 - mae: 0.8255 - val_loss: 1.1234 - val_mae: 0.7216 - learning_rate: 2.0000e-04
# Epoch 20/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2140 - mae: 0.8247 - val_loss: 1.1226 - val_mae: 0.7218 - learning_rate: 2.0000e-04
# Epoch 21/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2084 - mae: 0.8251 - val_loss: 1.1199 - val_mae: 0.7199 - learning_rate: 2.0000e-04
# Epoch 22/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2098 - mae: 0.8234 - val_loss: 1.1233 - val_mae: 0.7213 - learning_rate: 2.0000e-04
# Epoch 23/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2052 - mae: 0.8219 - val_loss: 1.1208 - val_mae: 0.7202 - learning_rate: 2.0000e-04
# Epoch 24/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2162 - mae: 0.8249 - val_loss: 1.1225 - val_mae: 0.7225 - learning_rate: 2.0000e-04
# Epoch 25/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2031 - mae: 0.8218 - val_loss: 1.1255 - val_mae: 0.7219 - learning_rate: 2.0000e-04
# Epoch 26/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2130 - mae: 0.8231 - val_loss: 1.1231 - val_mae: 0.7210 - learning_rate: 2.0000e-04
# Epoch 27/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2112 - mae: 0.8230 - val_loss: 1.1222 - val_mae: 0.7204 - learning_rate: 4.0000e-05
# Epoch 28/50
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 4.2117 - mae: 0.8234 - val_loss: 1.1224 - val_mae: 0.7209 - learning_rate: 4.0000e-05
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# Training model for NVDA...
# Epoch 1/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - loss: 2.8469 - mae: 1.0537 - val_loss: 1.7694 - val_mae: 0.8883 - learning_rate: 2.0000e-04
# Epoch 2/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.6219 - mae: 0.9478 - val_loss: 1.6818 - val_mae: 0.8443 - learning_rate: 2.0000e-04
# Epoch 3/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5821 - mae: 0.9238 - val_loss: 1.6774 - val_mae: 0.8404 - learning_rate: 2.0000e-04
# Epoch 4/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5649 - mae: 0.9156 - val_loss: 1.6809 - val_mae: 0.8417 - learning_rate: 2.0000e-04
# Epoch 5/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 2.5464 - mae: 0.9110 - val_loss: 1.6726 - val_mae: 0.8365 - learning_rate: 2.0000e-04
# Epoch 6/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - loss: 2.5518 - mae: 0.9084 - val_loss: 1.6539 - val_mae: 0.8312 - learning_rate: 2.0000e-04
# Epoch 7/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5464 - mae: 0.9078 - val_loss: 1.6535 - val_mae: 0.8317 - learning_rate: 2.0000e-04
# Epoch 8/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5424 - mae: 0.9039 - val_loss: 1.6528 - val_mae: 0.8295 - learning_rate: 2.0000e-04
# Epoch 9/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5383 - mae: 0.9036 - val_loss: 1.6511 - val_mae: 0.8294 - learning_rate: 2.0000e-04
# Epoch 10/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5331 - mae: 0.9035 - val_loss: 1.6550 - val_mae: 0.8303 - learning_rate: 2.0000e-04
# Epoch 11/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5453 - mae: 0.9045 - val_loss: 1.6551 - val_mae: 0.8301 - learning_rate: 2.0000e-04
# Epoch 12/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5391 - mae: 0.9023 - val_loss: 1.6495 - val_mae: 0.8291 - learning_rate: 2.0000e-04
# Epoch 13/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5324 - mae: 0.9010 - val_loss: 1.6596 - val_mae: 0.8336 - learning_rate: 2.0000e-04
# Epoch 14/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5352 - mae: 0.9002 - val_loss: 1.6576 - val_mae: 0.8341 - learning_rate: 2.0000e-04
# Epoch 15/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5359 - mae: 0.9007 - val_loss: 1.6512 - val_mae: 0.8314 - learning_rate: 2.0000e-04
# Epoch 16/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5343 - mae: 0.8992 - val_loss: 1.6472 - val_mae: 0.8270 - learning_rate: 2.0000e-04
# Epoch 17/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5305 - mae: 0.8985 - val_loss: 1.6468 - val_mae: 0.8269 - learning_rate: 2.0000e-04
# Epoch 18/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5402 - mae: 0.8989 - val_loss: 1.6692 - val_mae: 0.8359 - learning_rate: 2.0000e-04
# Epoch 19/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5404 - mae: 0.8994 - val_loss: 1.6480 - val_mae: 0.8261 - learning_rate: 2.0000e-04
# Epoch 20/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5336 - mae: 0.8974 - val_loss: 1.6563 - val_mae: 0.8310 - learning_rate: 2.0000e-04
# Epoch 21/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5342 - mae: 0.8975 - val_loss: 1.6517 - val_mae: 0.8297 - learning_rate: 2.0000e-04
# Epoch 22/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5387 - mae: 0.8988 - val_loss: 1.6501 - val_mae: 0.8284 - learning_rate: 2.0000e-04
# Epoch 23/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5312 - mae: 0.8971 - val_loss: 1.6419 - val_mae: 0.8245 - learning_rate: 4.0000e-05
# Epoch 24/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5295 - mae: 0.8948 - val_loss: 1.6415 - val_mae: 0.8241 - learning_rate: 4.0000e-05
# Epoch 25/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5230 - mae: 0.8935 - val_loss: 1.6418 - val_mae: 0.8239 - learning_rate: 4.0000e-05
# Epoch 26/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5256 - mae: 0.8943 - val_loss: 1.6396 - val_mae: 0.8234 - learning_rate: 4.0000e-05
# Epoch 27/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5259 - mae: 0.8947 - val_loss: 1.6398 - val_mae: 0.8232 - learning_rate: 4.0000e-05
# Epoch 28/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5209 - mae: 0.8937 - val_loss: 1.6408 - val_mae: 0.8236 - learning_rate: 4.0000e-05
# Epoch 29/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5283 - mae: 0.8955 - val_loss: 1.6415 - val_mae: 0.8243 - learning_rate: 4.0000e-05
# Epoch 30/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5226 - mae: 0.8948 - val_loss: 1.6418 - val_mae: 0.8245 - learning_rate: 4.0000e-05
# Epoch 31/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.5234 - mae: 0.8953 - val_loss: 1.6406 - val_mae: 0.8237 - learning_rate: 4.0000e-05
# Epoch 32/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5241 - mae: 0.8950 - val_loss: 1.6400 - val_mae: 0.8235 - learning_rate: 8.0000e-06
# Epoch 33/50
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.5175 - mae: 0.8931 - val_loss: 1.6402 - val_mae: 0.8234 - learning_rate: 8.0000e-06
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step
# Training model for TSLA...
# Epoch 1/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - loss: 2.3933 - mae: 0.9686 - val_loss: 1.5580 - val_mae: 0.8286 - learning_rate: 2.0000e-04
# Epoch 2/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.2849 - mae: 0.9152 - val_loss: 1.5233 - val_mae: 0.8096 - learning_rate: 2.0000e-04
# Epoch 3/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2613 - mae: 0.8992 - val_loss: 1.5037 - val_mae: 0.7983 - learning_rate: 2.0000e-04
# Epoch 4/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2482 - mae: 0.8927 - val_loss: 1.5301 - val_mae: 0.8099 - learning_rate: 2.0000e-04
# Epoch 5/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.2440 - mae: 0.8905 - val_loss: 1.5055 - val_mae: 0.7979 - learning_rate: 2.0000e-04
# Epoch 6/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2307 - mae: 0.8853 - val_loss: 1.4971 - val_mae: 0.7915 - learning_rate: 2.0000e-04
# Epoch 7/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2342 - mae: 0.8870 - val_loss: 1.4983 - val_mae: 0.7920 - learning_rate: 2.0000e-04
# Epoch 8/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2368 - mae: 0.8867 - val_loss: 1.4997 - val_mae: 0.7893 - learning_rate: 2.0000e-04
# Epoch 9/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.2299 - mae: 0.8829 - val_loss: 1.4931 - val_mae: 0.7885 - learning_rate: 2.0000e-04
# Epoch 10/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2330 - mae: 0.8833 - val_loss: 1.4907 - val_mae: 0.7870 - learning_rate: 2.0000e-04
# Epoch 11/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2283 - mae: 0.8816 - val_loss: 1.4879 - val_mae: 0.7858 - learning_rate: 2.0000e-04
# Epoch 12/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.2188 - mae: 0.8799 - val_loss: 1.4955 - val_mae: 0.7912 - learning_rate: 2.0000e-04
# Epoch 13/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.2266 - mae: 0.8805 - val_loss: 1.4875 - val_mae: 0.7868 - learning_rate: 2.0000e-04
# Epoch 14/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2304 - mae: 0.8817 - val_loss: 1.4843 - val_mae: 0.7854 - learning_rate: 2.0000e-04
# Epoch 15/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2168 - mae: 0.8794 - val_loss: 1.4859 - val_mae: 0.7852 - learning_rate: 2.0000e-04
# Epoch 16/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.2254 - mae: 0.8792 - val_loss: 1.4984 - val_mae: 0.7906 - learning_rate: 2.0000e-04
# Epoch 17/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - loss: 2.2223 - mae: 0.8776 - val_loss: 1.4899 - val_mae: 0.7891 - learning_rate: 2.0000e-04
# Epoch 18/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2235 - mae: 0.8798 - val_loss: 1.4874 - val_mae: 0.7861 - learning_rate: 2.0000e-04
# Epoch 19/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2243 - mae: 0.8808 - val_loss: 1.4892 - val_mae: 0.7866 - learning_rate: 2.0000e-04
# Epoch 20/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2149 - mae: 0.8775 - val_loss: 1.4874 - val_mae: 0.7856 - learning_rate: 4.0000e-05
# Epoch 21/50
# 581/581 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - loss: 2.2186 - mae: 0.8762 - val_loss: 1.4879 - val_mae: 0.7854 - learning_rate: 4.0000e-05
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step
# Training model for AMZN...
# Epoch 1/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - loss: 2.3040 - mae: 0.8971 - val_loss: 1.3873 - val_mae: 0.7963 - learning_rate: 2.0000e-04
# Epoch 2/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.2231 - mae: 0.8472 - val_loss: 1.3767 - val_mae: 0.7882 - learning_rate: 2.0000e-04
# Epoch 3/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 2.2155 - mae: 0.8331 - val_loss: 1.3629 - val_mae: 0.7783 - learning_rate: 2.0000e-04
# Epoch 4/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.2125 - mae: 0.8301 - val_loss: 1.3534 - val_mae: 0.7730 - learning_rate: 2.0000e-04
# Epoch 5/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1923 - mae: 0.8268 - val_loss: 1.3546 - val_mae: 0.7756 - learning_rate: 2.0000e-04
# Epoch 6/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 29ms/step - loss: 2.1928 - mae: 0.8240 - val_loss: 1.3446 - val_mae: 0.7719 - learning_rate: 2.0000e-04
# Epoch 7/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1941 - mae: 0.8230 - val_loss: 1.3483 - val_mae: 0.7725 - learning_rate: 2.0000e-04
# Epoch 8/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1904 - mae: 0.8214 - val_loss: 1.3411 - val_mae: 0.7685 - learning_rate: 2.0000e-04
# Epoch 9/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1839 - mae: 0.8180 - val_loss: 1.3472 - val_mae: 0.7727 - learning_rate: 2.0000e-04
# Epoch 10/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1824 - mae: 0.8180 - val_loss: 1.3377 - val_mae: 0.7652 - learning_rate: 2.0000e-04
# Epoch 11/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 2.1902 - mae: 0.8195 - val_loss: 1.3381 - val_mae: 0.7675 - learning_rate: 2.0000e-04
# Epoch 12/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1828 - mae: 0.8159 - val_loss: 1.3368 - val_mae: 0.7630 - learning_rate: 2.0000e-04
# Epoch 13/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1778 - mae: 0.8121 - val_loss: 1.3391 - val_mae: 0.7678 - learning_rate: 2.0000e-04
# Epoch 14/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1850 - mae: 0.8136 - val_loss: 1.3412 - val_mae: 0.7664 - learning_rate: 2.0000e-04
# Epoch 15/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1774 - mae: 0.8111 - val_loss: 1.3351 - val_mae: 0.7642 - learning_rate: 2.0000e-04
# Epoch 16/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1776 - mae: 0.8121 - val_loss: 1.3371 - val_mae: 0.7649 - learning_rate: 2.0000e-04
# Epoch 17/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 2.1770 - mae: 0.8120 - val_loss: 1.3511 - val_mae: 0.7772 - learning_rate: 2.0000e-04
# Epoch 18/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1804 - mae: 0.8146 - val_loss: 1.3368 - val_mae: 0.7661 - learning_rate: 2.0000e-04
# Epoch 19/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 2.1783 - mae: 0.8122 - val_loss: 1.3354 - val_mae: 0.7661 - learning_rate: 2.0000e-04
# Epoch 20/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1754 - mae: 0.8126 - val_loss: 1.3445 - val_mae: 0.7700 - learning_rate: 2.0000e-04
# Epoch 21/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 2.1756 - mae: 0.8107 - val_loss: 1.3419 - val_mae: 0.7685 - learning_rate: 4.0000e-05
# Epoch 22/50
# 519/519 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step - loss: 2.1777 - mae: 0.8115 - val_loss: 1.3411 - val_mae: 0.7680 - learning_rate: 4.0000e-05
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step
# Training model for META...
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 18s 27ms/step - loss: 1.9160 - mae: 0.8568 - val_loss: 1.1791 - val_mae: 0.7571 - learning_rate: 2.0000e-04
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8606 - mae: 0.8276 - val_loss: 1.1552 - val_mae: 0.7460 - learning_rate: 2.0000e-04
# Epoch 3/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8396 - mae: 0.8150 - val_loss: 1.1508 - val_mae: 0.7440 - learning_rate: 2.0000e-04
# Epoch 4/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8303 - mae: 0.8116 - val_loss: 1.1493 - val_mae: 0.7445 - learning_rate: 2.0000e-04
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8141 - mae: 0.8045 - val_loss: 1.1211 - val_mae: 0.7302 - learning_rate: 2.0000e-04
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8119 - mae: 0.8016 - val_loss: 1.1136 - val_mae: 0.7221 - learning_rate: 2.0000e-04
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8096 - mae: 0.8024 - val_loss: 1.1107 - val_mae: 0.7204 - learning_rate: 2.0000e-04
# Epoch 8/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8114 - mae: 0.8029 - val_loss: 1.1061 - val_mae: 0.7189 - learning_rate: 2.0000e-04
# Epoch 9/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - loss: 1.8103 - mae: 0.8002 - val_loss: 1.1168 - val_mae: 0.7267 - learning_rate: 2.0000e-04
# Epoch 10/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 27ms/step - loss: 1.8062 - mae: 0.7993 - val_loss: 1.1345 - val_mae: 0.7345 - learning_rate: 2.0000e-04
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8097 - mae: 0.7987 - val_loss: 1.1280 - val_mae: 0.7305 - learning_rate: 2.0000e-04
# Epoch 12/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8084 - mae: 0.7985 - val_loss: 1.1098 - val_mae: 0.7208 - learning_rate: 2.0000e-04
# Epoch 13/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8071 - mae: 0.7972 - val_loss: 1.1069 - val_mae: 0.7184 - learning_rate: 2.0000e-04
# Epoch 14/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8066 - mae: 0.7970 - val_loss: 1.1050 - val_mae: 0.7177 - learning_rate: 4.0000e-05
# Epoch 15/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8064 - mae: 0.7971 - val_loss: 1.1063 - val_mae: 0.7182 - learning_rate: 4.0000e-05
# Epoch 16/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8065 - mae: 0.7979 - val_loss: 1.1088 - val_mae: 0.7194 - learning_rate: 4.0000e-05
# Epoch 17/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8005 - mae: 0.7962 - val_loss: 1.1066 - val_mae: 0.7183 - learning_rate: 4.0000e-05
# Epoch 18/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.7989 - mae: 0.7949 - val_loss: 1.1047 - val_mae: 0.7172 - learning_rate: 4.0000e-05
# Epoch 19/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8051 - mae: 0.7975 - val_loss: 1.1041 - val_mae: 0.7173 - learning_rate: 4.0000e-05
# Epoch 20/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.8028 - mae: 0.7959 - val_loss: 1.1064 - val_mae: 0.7184 - learning_rate: 4.0000e-05
# Epoch 21/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8008 - mae: 0.7956 - val_loss: 1.1061 - val_mae: 0.7182 - learning_rate: 4.0000e-05
# Epoch 22/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8010 - mae: 0.7949 - val_loss: 1.1054 - val_mae: 0.7186 - learning_rate: 4.0000e-05
# Epoch 23/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.7969 - mae: 0.7948 - val_loss: 1.1051 - val_mae: 0.7182 - learning_rate: 4.0000e-05
# Epoch 24/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8018 - mae: 0.7955 - val_loss: 1.1057 - val_mae: 0.7188 - learning_rate: 4.0000e-05
# Epoch 25/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 1.8014 - mae: 0.7956 - val_loss: 1.1061 - val_mae: 0.7188 - learning_rate: 8.0000e-06
# Epoch 26/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - loss: 1.7997 - mae: 0.7946 - val_loss: 1.1063 - val_mae: 0.7188 - learning_rate: 8.0000e-06
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step

# %% [markdown]
# Plots

# %%
colors = ['tab:gray', 'tab:purple', 'tab:olive','tab:green', 'tab:red', 'tab:orange', 'tab:blue']

# Add rolling metrics
all_trades_df['Rolling_Risk'] = all_trades_df.groupby('Ticker')['Actual_Return'].transform(lambda x: x.rolling(window=10).std())
all_trades_df['Rolling_Average'] = all_trades_df.groupby('Ticker')['Actual_Return'].transform(lambda x: x.rolling(window=10).mean())

# Improved Trading Strategy Plot with consistent x-axis and grid
def plot_trading_strategy(all_trades_df):
    plt.figure(figsize=(14, 7))
    for ticker, color in zip(stocks, colors):
        ticker_data = all_trades_df[all_trades_df['Ticker'] == ticker]
        plt.plot(pd.to_datetime(ticker_data['Date']), ticker_data['Cumulative_Return'], label=ticker, color=color, linewidth=2)
    plt.title('Cumulative Trading Strategy Returns (All Stocks)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
plot_trading_strategy(all_trades_df)

# %%
# Improved Buy & Hold Plot with consistent datetime parsing
import matplotlib.colors as mcolors

def plot_buy_and_hold_test_period(df):
    plt.figure(figsize=(14, 7))
    for ticker, color in zip(stocks, colors):
        df_ticker = df[df['Ticker'] == ticker].sort_values('Datetime')
        df_test = df_ticker[df_ticker['Datetime'] >= '2025-03-01']

        if df_test.empty:
            continue

        buy_hold_returns = df_test['Close'] / df_test['Close'].iloc[0]
        # Use darker version of the color
        darker_color = mcolors.to_rgba(color, alpha=0.6)
        plt.plot(df_test['Datetime'], buy_hold_returns, label=f'{ticker}', color=darker_color, linestyle='--', linewidth=2)

    plt.title('Buy & Hold Returns (Test Period from March 1)')
    plt.xlabel('Date')
    plt.ylabel('Cumulative Return')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

plot_buy_and_hold_test_period(df)

# %%
def plot_trading_vs_buy_hold(df, all_trades_df):
    fig, axes = plt.subplots(1, 7, figsize=(30, 4))
    for ax, ticker, color in zip(axes, stocks, colors):
        trades = all_trades_df[all_trades_df['Ticker'] == ticker]
        df_ticker = df[df['Ticker'] == ticker].sort_values('Datetime')
        df_test = df_ticker[df_ticker['Datetime'] >= '2025-03-01']

        if df_test.empty or trades.empty:
            continue

        buy_hold_returns = df_test['Close'] / df_test['Close'].iloc[0]
        darker_color = mcolors.to_rgba(color, alpha=0.6)

        ax.plot(pd.to_datetime(trades['Date']), trades['Cumulative_Return'], color=color, label='Strategy', linewidth=2)
        ax.plot(df_test['Datetime'], buy_hold_returns, color=darker_color, linestyle='--', label='Buy & Hold', linewidth=2)

        ax.set_title(f'{ticker}')
        ax.grid(True)
        ax.tick_params(axis='x', rotation=30)

    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc='upper center', ncol=2, frameon=True, fontsize=10)
    plt.tight_layout()
    plt.show()


plot_trading_vs_buy_hold(df, all_trades_df)

# %%
# Compare final returns
def calculate_strategy_returns(df, all_trades_df):
    results = []
    for ticker in df['Ticker'].unique():
        df_ticker = df[df['Ticker'] == ticker].sort_values('Datetime')
        df_test = df_ticker[df_ticker['Datetime'] >= '2025-03-01']

        if df_test.empty:
            continue

        buy_and_hold_return = (df_test['Close'].iloc[-1] / df_test['Close'].iloc[0]) - 1

        df_trades = all_trades_df[all_trades_df['Ticker'] == ticker]
        strategy_return = df_trades['Cumulative_Return'].iloc[-1] - 1 if not df_trades.empty else None

        results.append({
            "Ticker": ticker,
            "Buy & Hold Return (%)": round(buy_and_hold_return * 100, 2),
            "Trading Strategy Return (%)": round(strategy_return * 100, 2) if strategy_return is not None else None
        })

    return pd.DataFrame(results)

# %%
strategy_returns_df = calculate_strategy_returns(df, all_trades_df)
print(strategy_returns_df)
# Out:
#   Ticker  Buy & Hold Return (%)  Trading Strategy Return (%)
# 0   AAPL                  -8.64                        14.44
# 1   AMZN                 -11.03                         9.69
# 2  GOOGL                  -9.92                         6.76
# 3   META                 -14.30                        29.53
# 4   MSFT                  -5.75                       -11.02
# 5   NVDA                 -13.87                        -5.66
# 6   TSLA                 -12.53                        18.97

# %%
strategy_returns_df_no_news = calculate_strategy_returns(df, all_trades_df_no_news)
print(strategy_returns_df_no_news)
# Out:
#   Ticker  Buy & Hold Return (%)  Trading Strategy Return (%)
# 0   AAPL                  -8.64                        21.65
# 1   AMZN                 -11.03                        -4.70
# 2  GOOGL                  -9.92                         6.22
# 3   META                 -14.30                       -10.33
# 4   MSFT                  -5.75                        -2.56
# 5   NVDA                 -13.87                        44.00
# 6   TSLA                 -12.53                        20.81

# %%
all_trades_df.head(5)
# Out:
#                  Date  Close_Price  Actual_Return  Predicted_Return Position  \
# 0 2025-03-03 09:00:00       241.55       0.009061         -0.000124    SHORT
# 1 2025-03-03 09:02:00       241.50      -0.000303         -0.000111    SHORT
# 2 2025-03-03 09:04:00       241.62      -0.001909         -0.000106    SHORT
# 3 2025-03-03 09:06:00       241.67      -0.000625         -0.000101    SHORT
# 4 2025-03-03 09:08:00       241.48      -0.000376         -0.000096    SHORT
#
#    Strategy_Return  Cumulative_Return Ticker  Rolling_Risk  Rolling_Average
# 0        -0.009061           0.990939   AAPL           NaN              NaN
# 1         0.000303           0.991239   AAPL           NaN              NaN
# 2         0.001909           0.993132   AAPL           NaN              NaN
# 3         0.000625           0.993753   AAPL           NaN              NaN
# 4         0.000376           0.994126   AAPL           NaN              NaN

# %%
all_trades_df.to_csv("returns.csv")
